# %% [markdown]
# <a href="https://colab.research.google.com/github/Alinawaz-hub/Alinawaz-hub/blob/main/imag_processing_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world! this is me Ali nawaz starting to do something. may this time i will put my all effort bcz if lost this time then no hope will remain ")
# Out:
# hello world! this is me Ali nawaz starting to do something. may this time i will put my all effort bcz if lost this time then no hope will remain

# %%
import tensorflow as tf

# %%
print (tf.__version__)
from google.colab.patches import cv2_imshow
# Out:
# 2.12.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimag
import skimage
from skimage import img_as_float

# %% [markdown]
# # New Section

# %%
import skimage                 # form 1, load whole skimage library
import skimage.draw            # form 2, load skimage.draw module only
from skimage.draw import disk  # form 3, load only the disk function
import numpy as np

# %%
from skimage import io
from PIL import Image

# %%
my_image = io.imread("test1.jpeg")
print(my_image.min(), my_image.max())
# Out:
# 2 255

# %%
#print(my_image)
plt.imshow(my_image)

# %%
random_ig = np.random.random([500,500])
plt.imshow(random_ig)
my_img__float = img_as_float(random_ig)
print(my_img__float)
print(my_img__float.min(), my_img__float.max())
# Out:
# [[0.9576097  0.87548279 0.54805249 ... 0.77245454 0.14494499 0.91159683]
#  [0.3568653  0.10056307 0.74377997 ... 0.63856039 0.26867167 0.02171957]
#  [0.75334736 0.90994708 0.1601128  ... 0.57533047 0.28139182 0.57054002]
#  ...
#  [0.86086521 0.07608564 0.55917184 ... 0.47414307 0.97646321 0.50354951]
#  [0.17111215 0.88375203 0.95718555 ... 0.36866432 0.51910249 0.50831994]
#  [0.93704849 0.22136191 0.27581038 ... 0.48758549 0.71410759 0.50227679]]
# 3.780060862990098e-06 0.9999983144379513

# %%
print(random_ig.min(), random_ig.max())
# Out:
# 1.2771902544450597e-06 0.9999997045354746

# %%
plt.imshow(my_img__float)

# %%
from numpy.lib.type_check import imag
img = Image.open("test1.jpeg")
print(type(img))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
print(img.format)
print(img)
plt.imshow(img)
# Out:
# JPEG
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x1280 at 0x7FBC955A0610>

# %%
img1 = np.asarray(img)
print(type(img1))
print(img1)
# Out:
# <class 'numpy.ndarray'>
# [[[180 178 192]
#   [159 176 184]
#   [132 166 168]
#   ...
#   [140 157 165]
#   [135 158 164]
#   [139 167 171]]
#
#  [[184 180 195]
#   [167 181 190]
#   [144 173 177]
#   ...
#   [148 161 170]
#   [144 163 170]
#   [149 172 178]]
#
#  [[179 172 188]
#   [166 174 185]
#   [148 168 175]
#   ...
#   [150 158 169]
#   [138 151 160]
#   [137 151 160]]
#
#  ...
#
#  [[166 118  96]
#   [167 121  95]
#   [147 106  78]
#   ...
#   [ 89  83  87]
#   [101  78  96]
#   [112  78 105]]
#
#  [[159 114  83]
#   [152 116  80]
#   [144 116  77]
#   ...
#   [107  80  89]
#   [116  76 102]
#   [125  73 109]]
#
#  [[151 119  80]
#   [146 123  79]
#   [146 136  87]
#   ...
#   [120  74  87]
#   [121  71  98]
#   [125  69 104]]]

# %%
img3= mpimag.imread("test1.jpeg")
print(img3)
# Out:
# [[[180 178 192]
#   [159 176 184]
#   [132 166 168]
#   ...
#   [140 157 165]
#   [135 158 164]
#   [139 167 171]]
#
#  [[184 180 195]
#   [167 181 190]
#   [144 173 177]
#   ...
#   [148 161 170]
#   [144 163 170]
#   [149 172 178]]
#
#  [[179 172 188]
#   [166 174 185]
#   [148 168 175]
#   ...
#   [150 158 169]
#   [138 151 160]
#   [137 151 160]]
#
#  ...
#
#  [[166 118  96]
#   [167 121  95]
#   [147 106  78]
#   ...
#   [ 89  83  87]
#   [101  78  96]
#   [112  78 105]]
#
#  [[159 114  83]
#   [152 116  80]
#   [144 116  77]
#   ...
#   [107  80  89]
#   [116  76 102]
#   [125  73 109]]
#
#  [[151 119  80]
#   [146 123  79]
#   [146 136  87]
#   ...
#   [120  74  87]
#   [121  71  98]
#   [125  69 104]]]

# %%
print(type(img3))
print(img3.shape)
# Out:
# <class 'numpy.ndarray'>
# (1280, 720, 3)

# %%
plt.imshow(img3)
plt.colorbar()

# %%
grey_image = cv2.imread('test1.jpeg',0)

color_image = cv2.imread('test1.jpeg',1)
plt.imshow(random_ig)

# %%
img4 = cv2.imread('color_image',0)
plt.imshow(cv2.cvtColor(img4,cv2.COLOR_BGR2RGB))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-ec444f18723c> in <cell line: 2>()
#       1 img4 = cv2.imread('color_image',0)
# ----> 2 plt.imshow(cv2.cvtColor(img4,cv2.COLOR_BGR2RGB))
#
# error: OpenCV(4.7.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
# factorial of given number
def factorial(n):

	# single line to find factorial
	return 1 if (n==1 or n==0) else n * factorial(n - 1)

# Driver Code
num = int(input("Enter the number : "))
print("Factorial of",num,"is",factorial(num))
# Out:
# Enter the number : 3
# Factorial of 3 is 6
